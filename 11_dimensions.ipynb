# %%
from utils.data import descriptions, colors8, locations7
from utils.vis import matrix, summarize

# %% [markdown]
# # Objects and locations
# ## Monkey

# %%
prompts = [f'A monkey {x}' for x in locations7]
matrix(prompts[:4])

# %%
summarize(prompts)

# %% [markdown]
# ## Child

# %%
prompts = [f'A child {x}' for x in locations7]
matrix(prompts[:4])

# %%
summarize(prompts)

# %% [markdown]
# # Objects and colors
# ## Car

# %%
prompts = [f'A picture of a {x} car' for x in colors8]
matrix(prompts[:4])

# %%
summarize(prompts)

# %% [markdown]
# ## Pullover

# %%
prompts = [f'A picture of a {x} pullover' for x in colors8]
matrix(prompts[:4])

# %%
summarize(prompts)
